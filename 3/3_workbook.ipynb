# %% [markdown]
# <a href="https://colab.research.google.com/github/RDeconomist/RDeconomist.github.io/blob/main/data/DSEP_2_0_loopsExamples.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Richard Davies** Data Science for Economics and Policy - 2023
#
# **Tutorial**: First loops

# %% [markdown]
# Loop tutorials will typically start with an example like the one below - lets take a look.

# %%
locations = ["Swansea", "Cardiff", "Newport"]

## OK so we have a list of locations.

## One rule to remember is that indexing starts at 0. So the array above has positions 0, 1 and 2. Asking for position 3--which would seem to be Newport--will throw an error.

## If we want to retrive the locations we can therefore write:

print(locations[0])
print(locations[1])
print(locations[2])

## Try this!
# Out:
# Darlington
# Newport
# London

# %% [markdown]
# Any time we have repetitive code like the above, we should consider a loop. This is not just to show off. Manually copying code like the above leads to errors, and it is time consuming. Loops make you more accrate, and more efficient.

# %%
## Here is our first loop:

locations = ["Darlington", "London", "Newport"]

for location in locations:
  print(location)
# Out:
# Darlington
# London
# Newport

# %% [markdown]
# A note on coding norms. I find the usage above really confusing. It seems to suggest that the singluar/plural matters in some way. For example, you will see lots of tutorials where you have "for fruit in fruits" or something of this nature.
#
# The names themselves can be ignored, it is what they represent that matters. In the first line we define list of locations. The name that comes after the for is just an indentifier that iterates over list.

# %%
placeList = ["Darlington", "Newport", "London"]
for i in placeList:
  print(i)
# Out:
# Darlington
# Newport
# London

# %% [markdown]
# Lets pause to discuss this. For those of you that understand loops already, how can you mend the following code: (a) so that it works, and (b) so that it makes sense to a human?

# %%
words = ["lovely", "city", "is", "a", "Darlington"]
numbers = [1,2,3,4,5]
for i in numbers:
  print(words)
  print(words[i])

# %%
## Here is some mended code:

words = ["lovely", "city", "is", "a", "Darlington"]
numbers = [0,1,2,3,4]
richard = [4,2,3,0,1]

for i in numbers:
  print(words[i])

print("\n") # This is just a new line. Not needed just makes a break between the output.

for x in richard:
  print(words[x])
# Out:
# lovely
# city
# is
# a
# Darlington
#
#
# Darlington
# is
# a
# lovely
# city

# %% [markdown]
# **Tutorial:** Using loops to batch download data from an API
#
# **Motivation:** You are asked by your Minister to build a dashboard for the US economy. This must take in 10 important series, each of them plotted with a line chart. The data will need to be re-downloaded each month, meaning that you are manually downloading 120 series per year, in order to keep your dashboard up to date. How can we bath process this, so that all downloads are done with one click?

# %%
# Preliminaries 1 - the format() method:
# See: https://www.w3schools.com/python/ref_string_format.asp

# Take a sentence, and put a placeholder {} where we want to insert something:
sentence = "The best rugby team in the world is {}"
# Now we can use .format() to insert something into this place:
sentence.format('Wales')
# Out:
# 'The best rugby team in the world is Wales'

# %%
# Note: 'format()' method is a pre-defined piece of code that you must use;
# But 'sentence' is just a variable name, it can be anything:
x = "The best football team in the world is {}"
x.format('Manchester United')
# Out:
# 'The best football team in the world is Manchester United'

# %%
# Next note that we can put a variable within the format():
sentence = "The best team this year is {}"
team = 'Manchester City'
sentence.format(team)
# This allows us to change the sentence
# Out:
# 'The best team this year is Manchester City'

# %%
# // PRELIMINARIES 2 - Using the format method in a loop:

sentence = "The best team is {}"
teams = [
    'Manchester United', 'AC Milan', 'Barcelona', 'PSG', 'Bayern Munich',
    'River Plate'
]

# // Begin a loop, dealing with series one by one:
for i in teams:

    # // Everything that follows the for loop is indented. (On my machine, three spaces)
    # // Build the URL for this iteration of the loop, and check what we are getting:
    topTeam = sentence.format(i)
    print(topTeam)
# Out:
# The best team is Manchester United
# The best team is AC Milan
# The best team is Barcelona
# The best team is PSG
# The best team is Bayern Munich
# The best team is River Plate

# %%
# // PUTTING THINGS TOGETHER 1 - A loop of all our variables:

# // Set a base URL.
# // This includes everthing that does not change in our loop.
# // And a placeholder "{}" for the part that does change.
url_base = "https://api.stlouisfed.org/fred/series/observations?series_id={}&api_key=22ee7a76e736e32f54f5df0a7171538d&file_type=json"

# NOW PICK ALL THE SERIES THAT WE ARE INTERESTED IN:
fredSeries = [
    'PCEPI', 'CPIAUCSL', 'PAYEMS', 'DGS10', 'INDPRO', 'UNRATE',
    'LES1252881600Q'
]

# // Begin a loop, dealing with series one by one:
for i in fredSeries:
    # // Build the URL for this iteration of the loop, and check what we are getting:
    URL = url_base.format(i)
    print(URL)
# Out:
# https://api.stlouisfed.org/fred/series/observations?series_id=PCEPI&api_key=22ee7a76e736e32f54f5df0a7171538d&file_type=json
# https://api.stlouisfed.org/fred/series/observations?series_id=CPIAUCSL&api_key=22ee7a76e736e32f54f5df0a7171538d&file_type=json
# https://api.stlouisfed.org/fred/series/observations?series_id=PAYEMS&api_key=22ee7a76e736e32f54f5df0a7171538d&file_type=json
# https://api.stlouisfed.org/fred/series/observations?series_id=DGS10&api_key=22ee7a76e736e32f54f5df0a7171538d&file_type=json
# https://api.stlouisfed.org/fred/series/observations?series_id=INDPRO&api_key=22ee7a76e736e32f54f5df0a7171538d&file_type=json
# https://api.stlouisfed.org/fred/series/observations?series_id=UNRATE&api_key=22ee7a76e736e32f54f5df0a7171538d&file_type=json
# https://api.stlouisfed.org/fred/series/observations?series_id=LES1252881600Q&api_key=22ee7a76e736e32f54f5df0a7171538d&file_type=json

# %%
# // PUTTING THINGS TOGETHER 2 - Importing some tools that we will need:

# // Opening web sites and web scraping:
import requests

# // JSON. This helps us make JSON look prettier and easier to read
import json

# /// Files.  This is part of Collab - allows you to upload and download files
from google.colab import files

# // OS. Sometimes need this for finding working directory:
import os

# %%
## // An aside: checking which versions of thins are running
print(requests.__version__)
print(json.__version__)
# Out:
# 2.28.0
# 2.0.9

# %%
## // Getting data from a single API call:

url = "https://api.stlouisfed.org/fred/series/observations?series_id=DGS10&api_key=22ee7a76e736e32f54f5df0a7171538d&file_type=json"

# We use'requests' which we installed above:
data = requests.get(url).json()

# Print what we got
data
# Out:
# {'realtime_start': '2024-02-14',
#  'realtime_end': '2024-02-14',
#  'observation_start': '1600-01-01',
#  'observation_end': '9999-12-31',
#  'units': 'lin',
#  'output_type': 1,
#  'file_type': 'json',
#  'order_by': 'observation_date',
#  'sort_order': 'asc',
#  'count': 16205,
#  'offset': 0,
#  'limit': 100000,
#  'observations': [{'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-01-02',
#    'value': '4.06'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-01-03',
#    'value': '4.03'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-01-04',
#    'value': '3.99'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-01-05',
#    'value': '4.02'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-01-08',
#    'value': '4.03'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-01-09',
#    'value': '4.05'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-01-10',
#    'value': '4.07'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-01-11',
#    'value': '4.08'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-01-12',
#    'value': '4.08'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-01-15',
#    'value': '4.10'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-01-16',
#    'value': '4.13'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-01-17',
#    'value': '4.12'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-01-18',
#    'value': '4.11'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-01-19',
#    'value': '4.11'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-01-22',
#    'value': '4.09'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-01-23',
#    'value': '4.11'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-01-24',
#    'value': '4.10'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-01-25',
#    'value': '4.11'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-01-26',
#    'value': '4.11'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-01-29',
#    'value': '4.12'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-01-30',
#    'value': '4.11'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-01-31',
#    'value': '4.10'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-02-01',
#    'value': '4.09'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-02-02',
#    'value': '4.08'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-02-05',
#    'value': '4.07'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-02-06',
#    'value': '4.06'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-02-07',
#    'value': '4.07'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-02-08',
#    'value': '4.07'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-02-09',
#    'value': '4.05'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-02-12',
#    'value': '.'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-02-13',
#    'value': '4.03'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-02-14',
#    'value': '4.03'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-02-15',
#    'value': '4.02'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-02-16',
#    'value': '4.02'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-02-19',
#    'value': '4.01'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-02-20',
#    'value': '4.05'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-02-21',
#    'value': '4.03'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-02-22',
#    'value': '.'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-02-23',
#    'value': '4.02'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-02-26',
#    'value': '4.00'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-02-27',
#    'value': '4.01'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-02-28',
#    'value': '4.00'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-03-01',
#    'value': '3.98'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-03-02',
#    'value': '3.98'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-03-05',
#    'value': '4.00'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-03-06',
#    'value': '4.01'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-03-07',
#    'value': '4.00'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-03-08',
#    'value': '3.98'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-03-09',
#    'value': '3.96'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-03-12',
#    'value': '3.94'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-03-13',
#    'value': '3.92'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-03-14',
#    'value': '3.93'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-03-15',
#    'value': '3.96'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-03-16',
#    'value': '3.96'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-03-19',
#    'value': '3.93'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-03-20',
#    'value': '3.91'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-03-21',
#    'value': '3.86'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-03-22',
#    'value': '3.83'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-03-23',
#    'value': '3.87'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-03-26',
#    'value': '3.89'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-03-27',
#    'value': '3.90'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-03-28',
#    'value': '3.90'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-03-29',
#    'value': '3.90'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-03-30',
#    'value': '3.86'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-04-02',
#    'value': '3.86'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-04-03',
#    'value': '3.83'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-04-04',
#    'value': '3.78'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-04-05',
#    'value': '3.84'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-04-06',
#    'value': '3.81'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-04-09',
#    'value': '3.83'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-04-10',
#    'value': '3.83'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-04-11',
#    'value': '3.87'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-04-12',
#    'value': '3.86'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-04-13',
#    'value': '3.85'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-04-16',
#    'value': '3.83'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-04-17',
#    'value': '3.82'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-04-18',
#    'value': '3.81'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-04-19',
#    'value': '3.82'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-04-20',
#    'value': '.'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-04-23',
#    'value': '3.86'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-04-24',
#    'value': '3.87'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-04-25',
#    'value': '3.88'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-04-26',
#    'value': '3.89'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-04-27',
#    'value': '3.86'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-04-30',
#    'value': '3.86'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-05-01',
#    'value': '3.85'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-05-02',
#    'value': '3.86'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-05-03',
#    'value': '3.86'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-05-04',
#    'value': '3.87'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-05-07',
#    'value': '3.86'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-05-08',
#    'value': '3.85'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-05-09',
#    'value': '3.82'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-05-10',
#    'value': '3.83'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-05-11',
#    'value': '3.82'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-05-14',
#    'value': '3.85'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-05-15',
#    'value': '3.87'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-05-16',
#    'value': '3.86'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-05-17',
#    'value': '3.87'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-05-18',
#    'value': '3.93'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-05-21',
#    'value': '3.94'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-05-22',
#    'value': '3.93'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-05-23',
#    'value': '3.91'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-05-24',
#    'value': '3.90'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-05-25',
#    'value': '3.88'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-05-28',
#    'value': '3.87'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-05-29',
#    'value': '3.89'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-05-30',
#    'value': '.'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-05-31',
#    'value': '3.90'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-06-01',
#    'value': '3.89'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-06-04',
#    'value': '3.88'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-06-05',
#    'value': '3.89'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-06-06',
#    'value': '3.89'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-06-07',
#    'value': '3.87'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-06-08',
#    'value': '3.86'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-06-11',
#    'value': '3.87'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-06-12',
#    'value': '3.86'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-06-13',
#    'value': '3.87'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-06-14',
#    'value': '3.90'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-06-15',
#    'value': '3.89'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-06-18',
#    'value': '3.91'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-06-19',
#    'value': '3.93'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-06-20',
#    'value': '3.92'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-06-21',
#    'value': '3.90'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-06-22',
#    'value': '3.90'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-06-25',
#    'value': '3.95'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-06-26',
#    'value': '3.97'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-06-27',
#    'value': '3.96'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-06-28',
#    'value': '3.98'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-06-29',
#    'value': '4.00'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-07-02',
#    'value': '4.00'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-07-03',
#    'value': '4.00'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-07-04',
#    'value': '.'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-07-05',
#    'value': '4.00'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-07-06',
#    'value': '4.02'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-07-09',
#    'value': '4.05'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-07-10',
#    'value': '4.02'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-07-11',
#    'value': '3.99'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-07-12',
#    'value': '4.00'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-07-13',
#    'value': '4.00'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-07-16',
#    'value': '4.01'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-07-17',
#    'value': '4.03'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-07-18',
#    'value': '4.02'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-07-19',
#    'value': '4.02'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-07-20',
#    'value': '4.01'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-07-23',
#    'value': '4.00'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-07-24',
#    'value': '4.01'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-07-25',
#    'value': '4.02'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-07-26',
#    'value': '4.01'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-07-27',
#    'value': '4.02'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-07-30',
#    'value': '4.03'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-07-31',
#    'value': '4.04'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-08-01',
#    'value': '4.03'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-08-02',
#    'value': '4.00'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-08-03',
#    'value': '4.01'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-08-06',
#    'value': '4.01'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-08-07',
#    'value': '4.02'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-08-08',
#    'value': '4.01'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-08-09',
#    'value': '3.99'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-08-10',
#    'value': '3.99'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-08-13',
#    'value': '3.99'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-08-14',
#    'value': '3.98'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-08-15',
#    'value': '3.98'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-08-16',
#    'value': '3.96'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-08-17',
#    'value': '3.96'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-08-20',
#    'value': '3.94'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-08-21',
#    'value': '3.94'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-08-22',
#    'value': '3.95'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-08-23',
#    'value': '3.95'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-08-24',
#    'value': '3.95'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-08-27',
#    'value': '3.95'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-08-28',
#    'value': '3.96'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-08-29',
#    'value': '3.96'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-08-30',
#    'value': '3.95'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-08-31',
#    'value': '3.96'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-09-03',
#    'value': '.'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-09-04',
#    'value': '3.96'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-09-05',
#    'value': '3.97'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-09-06',
#    'value': '3.99'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-09-07',
#    'value': '4.01'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-09-10',
#    'value': '4.00'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-09-11',
#    'value': '4.00'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-09-12',
#    'value': '4.00'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-09-13',
#    'value': '3.99'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-09-14',
#    'value': '3.99'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-09-17',
#    'value': '3.99'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-09-18',
#    'value': '3.98'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-09-19',
#    'value': '3.99'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-09-20',
#    'value': '3.98'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-09-21',
#    'value': '3.98'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-09-24',
#    'value': '3.97'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-09-25',
#    'value': '3.96'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-09-26',
#    'value': '3.95'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-09-27',
#    'value': '3.95'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-09-28',
#    'value': '3.94'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-10-01',
#    'value': '3.93'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-10-02',
#    'value': '3.92'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-10-03',
#    'value': '3.90'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-10-04',
#    'value': '3.90'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-10-05',
#    'value': '3.92'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-10-08',
#    'value': '3.93'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-10-09',
#    'value': '3.95'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-10-10',
#    'value': '3.93'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-10-11',
#    'value': '3.94'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-10-12',
#    'value': '.'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-10-15',
#    'value': '3.94'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-10-16',
#    'value': '3.94'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-10-17',
#    'value': '3.94'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-10-18',
#    'value': '3.92'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-10-19',
#    'value': '3.88'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-10-22',
#    'value': '3.91'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-10-23',
#    'value': '3.94'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-10-24',
#    'value': '3.94'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-10-25',
#    'value': '3.94'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-10-26',
#    'value': '3.93'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-10-29',
#    'value': '3.92'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-10-30',
#    'value': '3.92'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-10-31',
#    'value': '3.92'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-11-01',
#    'value': '3.92'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-11-02',
#    'value': '3.91'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-11-05',
#    'value': '3.91'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-11-06',
#    'value': '.'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-11-07',
#    'value': '3.91'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-11-08',
#    'value': '3.90'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-11-09',
#    'value': '3.89'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-11-12',
#    'value': '.'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-11-13',
#    'value': '3.90'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-11-14',
#    'value': '3.91'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-11-15',
#    'value': '3.91'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-11-16',
#    'value': '3.93'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-11-19',
#    'value': '3.93'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-11-20',
#    'value': '3.93'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-11-21',
#    'value': '3.92'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-11-22',
#    'value': '.'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-11-23',
#    'value': '3.92'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-11-26',
#    'value': '3.93'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-11-27',
#    'value': '3.92'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-11-28',
#    'value': '3.92'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-11-29',
#    'value': '3.92'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-11-30',
#    'value': '3.92'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-12-03',
#    'value': '3.93'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-12-04',
#    'value': '3.94'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-12-05',
#    'value': '3.93'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-12-06',
#    'value': '3.92'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-12-07',
#    'value': '3.91'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-12-10',
#    'value': '3.90'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-12-11',
#    'value': '3.89'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-12-12',
#    'value': '3.88'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-12-13',
#    'value': '3.88'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-12-14',
#    'value': '3.87'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-12-17',
#    'value': '3.85'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-12-18',
#    'value': '3.83'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-12-19',
#    'value': '3.84'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-12-20',
#    'value': '3.83'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-12-21',
#    'value': '3.81'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-12-24',
#    'value': '3.79'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-12-25',
#    'value': '.'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-12-26',
#    'value': '3.79'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-12-27',
#    'value': '3.81'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-12-28',
#    'value': '3.84'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1962-12-31',
#    'value': '3.85'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-01-01',
#    'value': '.'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-01-02',
#    'value': '3.82'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-01-03',
#    'value': '3.81'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-01-04',
#    'value': '3.84'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-01-07',
#    'value': '3.83'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-01-08',
#    'value': '3.81'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-01-09',
#    'value': '3.82'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-01-10',
#    'value': '3.81'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-01-11',
#    'value': '3.80'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-01-14',
#    'value': '3.81'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-01-15',
#    'value': '3.80'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-01-16',
#    'value': '3.80'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-01-17',
#    'value': '3.82'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-01-18',
#    'value': '3.84'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-01-21',
#    'value': '3.85'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-01-22',
#    'value': '3.86'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-01-23',
#    'value': '3.86'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-01-24',
#    'value': '3.86'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-01-25',
#    'value': '3.85'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-01-28',
#    'value': '3.86'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-01-29',
#    'value': '3.86'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-01-30',
#    'value': '3.86'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-01-31',
#    'value': '3.87'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-02-01',
#    'value': '3.88'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-02-04',
#    'value': '3.89'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-02-05',
#    'value': '3.90'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-02-06',
#    'value': '3.91'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-02-07',
#    'value': '3.91'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-02-08',
#    'value': '3.91'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-02-11',
#    'value': '3.92'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-02-12',
#    'value': '.'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-02-13',
#    'value': '3.92'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-02-14',
#    'value': '3.91'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-02-15',
#    'value': '3.91'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-02-18',
#    'value': '3.91'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-02-19',
#    'value': '3.93'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-02-20',
#    'value': '3.94'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-02-21',
#    'value': '3.95'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-02-22',
#    'value': '.'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-02-25',
#    'value': '3.95'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-02-26',
#    'value': '3.95'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-02-27',
#    'value': '3.95'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-02-28',
#    'value': '3.94'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-03-01',
#    'value': '3.93'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-03-04',
#    'value': '3.92'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-03-05',
#    'value': '3.92'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-03-06',
#    'value': '3.91'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-03-07',
#    'value': '3.92'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-03-08',
#    'value': '3.92'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-03-11',
#    'value': '3.92'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-03-12',
#    'value': '3.92'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-03-13',
#    'value': '3.92'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-03-14',
#    'value': '3.92'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-03-15',
#    'value': '3.92'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-03-18',
#    'value': '3.92'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-03-19',
#    'value': '3.92'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-03-20',
#    'value': '3.92'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-03-21',
#    'value': '3.92'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-03-22',
#    'value': '3.93'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-03-25',
#    'value': '3.94'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-03-26',
#    'value': '3.96'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-03-27',
#    'value': '3.96'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-03-28',
#    'value': '3.96'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-03-29',
#    'value': '3.95'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-04-01',
#    'value': '3.95'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-04-02',
#    'value': '3.96'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-04-03',
#    'value': '3.96'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-04-04',
#    'value': '3.95'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-04-05',
#    'value': '3.95'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-04-08',
#    'value': '3.97'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-04-09',
#    'value': '3.98'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-04-10',
#    'value': '4.00'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-04-11',
#    'value': '4.00'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-04-12',
#    'value': '.'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-04-15',
#    'value': '4.01'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-04-16',
#    'value': '4.00'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-04-17',
#    'value': '4.00'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-04-18',
#    'value': '3.99'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-04-19',
#    'value': '3.97'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-04-22',
#    'value': '3.97'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-04-23',
#    'value': '3.97'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-04-24',
#    'value': '3.96'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-04-25',
#    'value': '3.95'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-04-26',
#    'value': '3.95'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-04-29',
#    'value': '3.95'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-04-30',
#    'value': '3.95'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-05-01',
#    'value': '3.94'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-05-02',
#    'value': '3.94'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-05-03',
#    'value': '3.93'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-05-06',
#    'value': '3.92'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-05-07',
#    'value': '3.91'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-05-08',
#    'value': '3.92'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-05-09',
#    'value': '3.93'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-05-10',
#    'value': '3.93'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-05-13',
#    'value': '3.92'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-05-14',
#    'value': '3.91'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-05-15',
#    'value': '3.91'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-05-16',
#    'value': '3.90'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-05-17',
#    'value': '3.92'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-05-20',
#    'value': '3.93'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-05-21',
#    'value': '3.92'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-05-22',
#    'value': '3.92'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-05-23',
#    'value': '3.93'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-05-24',
#    'value': '3.95'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-05-27',
#    'value': '3.95'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-05-28',
#    'value': '3.96'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-05-29',
#    'value': '3.96'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-05-30',
#    'value': '.'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-05-31',
#    'value': '3.96'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-06-03',
#    'value': '3.98'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-06-04',
#    'value': '3.98'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-06-05',
#    'value': '3.98'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-06-06',
#    'value': '3.99'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-06-07',
#    'value': '3.99'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-06-10',
#    'value': '3.99'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-06-11',
#    'value': '3.98'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-06-12',
#    'value': '3.99'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-06-13',
#    'value': '3.99'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-06-14',
#    'value': '3.99'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-06-17',
#    'value': '4.00'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-06-18',
#    'value': '4.00'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-06-19',
#    'value': '4.00'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-06-20',
#    'value': '4.00'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-06-21',
#    'value': '4.00'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-06-24',
#    'value': '4.00'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-06-25',
#    'value': '4.00'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-06-26',
#    'value': '4.00'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-06-27',
#    'value': '4.00'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-06-28',
#    'value': '4.00'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-07-01',
#    'value': '4.01'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-07-02',
#    'value': '4.03'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-07-03',
#    'value': '4.03'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-07-04',
#    'value': '.'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-07-05',
#    'value': '4.04'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-07-08',
#    'value': '4.05'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-07-09',
#    'value': '4.04'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-07-10',
#    'value': '4.03'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-07-11',
#    'value': '4.04'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-07-12',
#    'value': '4.03'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-07-15',
#    'value': '4.02'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-07-16',
#    'value': '4.02'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-07-17',
#    'value': '4.03'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-07-18',
#    'value': '4.02'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-07-19',
#    'value': '4.02'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-07-22',
#    'value': '4.02'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-07-23',
#    'value': '4.02'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-07-24',
#    'value': '4.01'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-07-25',
#    'value': '4.01'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-07-26',
#    'value': '3.99'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-07-29',
#    'value': '3.99'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-07-30',
#    'value': '4.00'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-07-31',
#    'value': '4.00'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-08-01',
#    'value': '3.99'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-08-02',
#    'value': '3.99'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-08-05',
#    'value': '3.99'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-08-06',
#    'value': '4.00'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-08-07',
#    'value': '4.01'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1963-08-08',
#    'value': '4.00'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
# ...
#    'value': '4.21'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-04-20',
#    'value': '4.21'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-04-21',
#    'value': '4.21'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-04-22',
#    'value': '4.21'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-04-23',
#    'value': '4.21'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-04-26',
#    'value': '4.21'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-04-27',
#    'value': '4.21'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-04-28',
#    'value': '4.21'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-04-29',
#    'value': '4.21'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-04-30',
#    'value': '4.21'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-05-03',
#    'value': '4.21'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-05-04',
#    'value': '4.20'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-05-05',
#    'value': '4.20'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-05-06',
#    'value': '4.20'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-05-07',
#    'value': '4.20'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-05-10',
#    'value': '4.20'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-05-11',
#    'value': '4.20'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-05-12',
#    'value': '4.20'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-05-13',
#    'value': '4.21'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-05-14',
#    'value': '4.21'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-05-17',
#    'value': '4.21'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-05-18',
#    'value': '4.22'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-05-19',
#    'value': '4.22'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-05-20',
#    'value': '4.22'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-05-21',
#    'value': '4.22'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-05-24',
#    'value': '4.22'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-05-25',
#    'value': '4.22'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-05-26',
#    'value': '4.22'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-05-27',
#    'value': '4.22'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-05-28',
#    'value': '4.23'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-05-31',
#    'value': '.'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-06-01',
#    'value': '4.23'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-06-02',
#    'value': '4.23'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-06-03',
#    'value': '4.23'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-06-04',
#    'value': '4.23'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-06-07',
#    'value': '4.23'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-06-08',
#    'value': '4.23'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-06-09',
#    'value': '4.23'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-06-10',
#    'value': '4.23'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-06-11',
#    'value': '4.23'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-06-14',
#    'value': '4.21'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-06-15',
#    'value': '4.21'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-06-16',
#    'value': '4.21'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-06-17',
#    'value': '4.21'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-06-18',
#    'value': '4.21'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-06-21',
#    'value': '4.20'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-06-22',
#    'value': '4.20'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-06-23',
#    'value': '4.20'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-06-24',
#    'value': '4.19'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-06-25',
#    'value': '4.19'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-06-28',
#    'value': '4.19'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-06-29',
#    'value': '4.20'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-06-30',
#    'value': '4.20'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-07-01',
#    'value': '4.20'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-07-02',
#    'value': '4.21'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-07-05',
#    'value': '.'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-07-06',
#    'value': '4.21'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-07-07',
#    'value': '4.21'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-07-08',
#    'value': '4.20'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-07-09',
#    'value': '4.21'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-07-12',
#    'value': '4.21'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-07-13',
#    'value': '4.21'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-07-14',
#    'value': '4.21'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-07-15',
#    'value': '4.20'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-07-16',
#    'value': '4.20'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-07-19',
#    'value': '4.20'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-07-20',
#    'value': '4.20'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-07-21',
#    'value': '4.20'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-07-22',
#    'value': '4.20'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-07-23',
#    'value': '4.20'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-07-26',
#    'value': '4.20'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-07-27',
#    'value': '4.20'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-07-28',
#    'value': '4.20'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-07-29',
#    'value': '4.21'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-07-30',
#    'value': '4.22'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-08-02',
#    'value': '4.22'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-08-03',
#    'value': '4.22'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-08-04',
#    'value': '4.23'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-08-05',
#    'value': '4.23'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-08-06',
#    'value': '4.24'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-08-09',
#    'value': '4.24'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-08-10',
#    'value': '4.24'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-08-11',
#    'value': '4.25'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-08-12',
#    'value': '4.25'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-08-13',
#    'value': '4.25'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-08-16',
#    'value': '4.26'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-08-17',
#    'value': '4.27'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-08-18',
#    'value': '4.26'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-08-19',
#    'value': '4.26'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-08-20',
#    'value': '4.26'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-08-23',
#    'value': '4.26'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-08-24',
#    'value': '4.27'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-08-25',
#    'value': '4.26'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-08-26',
#    'value': '4.27'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-08-27',
#    'value': '4.27'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-08-30',
#    'value': '4.27'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-08-31',
#    'value': '4.27'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-09-01',
#    'value': '4.28'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-09-02',
#    'value': '4.28'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-09-03',
#    'value': '4.27'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-09-06',
#    'value': '.'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-09-07',
#    'value': '4.27'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-09-08',
#    'value': '4.27'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-09-09',
#    'value': '4.27'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-09-10',
#    'value': '4.28'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-09-13',
#    'value': '4.28'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-09-14',
#    'value': '4.28'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-09-15',
#    'value': '4.28'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-09-16',
#    'value': '4.27'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-09-17',
#    'value': '4.27'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-09-20',
#    'value': '4.27'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-09-21',
#    'value': '4.28'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-09-22',
#    'value': '4.29'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-09-23',
#    'value': '4.30'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-09-24',
#    'value': '4.31'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-09-27',
#    'value': '4.31'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-09-28',
#    'value': '4.33'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-09-29',
#    'value': '4.36'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-09-30',
#    'value': '4.35'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-10-01',
#    'value': '4.36'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-10-04',
#    'value': '4.35'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-10-05',
#    'value': '4.33'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-10-06',
#    'value': '4.32'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-10-07',
#    'value': '4.31'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-10-08',
#    'value': '4.32'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-10-11',
#    'value': '4.31'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-10-12',
#    'value': '.'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-10-13',
#    'value': '4.30'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-10-14',
#    'value': '4.31'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-10-15',
#    'value': '4.34'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-10-18',
#    'value': '4.34'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-10-19',
#    'value': '4.35'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-10-20',
#    'value': '4.36'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-10-21',
#    'value': '4.37'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-10-22',
#    'value': '4.36'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-10-25',
#    'value': '4.38'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-10-26',
#    'value': '4.38'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-10-27',
#    'value': '4.39'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-10-28',
#    'value': '4.40'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-10-29',
#    'value': '4.41'},
#   {'realtime_start': '2024-02-14',
#    'realtime_end': '2024-02-14',
#    'date': '1965-11-01',
#    'value': '4.43'},
#   ...]}

# %%
# // Downloading the date from a single API call:

# // Based on the steps above, we have a variable "data" which has data on the US Government 10 year yield.

# // Set the filename, and check what we are getting:
fileName = "data_FRED-DGS10.json"
print(fileName)
# // Note: again the file name can be anything.

# /// Save the file:
with open(fileName, 'w', encoding='utf-8') as f:
    json.dump(data, f, ensure_ascii=False, indent=4)

# /// Download the file to local machine:
files.download('data_FRED-DGS10.json')
# Out:
# data_FRED-DGS10.json
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# e:\OneDrive\Github\eco\courses\archive\section2\DSEP_2_0_loopsExamples.ipynb Cell 22 in <cell line: 15>()
#      <a href='vscode-notebook-cell:/e%3A/OneDrive/Github/eco/courses/archive/section2/DSEP_2_0_loopsExamples.ipynb#X31sZmlsZQ%3D%3D?line=11'>12</a>     json.dump(data, f, ensure_ascii=False, indent=4)
#      <a href='vscode-notebook-cell:/e%3A/OneDrive/Github/eco/courses/archive/section2/DSEP_2_0_loopsExamples.ipynb#X31sZmlsZQ%3D%3D?line=13'>14</a> # /// Download the file to local machine:
# ---> <a href='vscode-notebook-cell:/e%3A/OneDrive/Github/eco/courses/archive/section2/DSEP_2_0_loopsExamples.ipynb#X31sZmlsZQ%3D%3D?line=14'>15</a> files.download('data_FRED-DGS10.json')
#
# NameError: name 'files' is not defined

# %%
# // PUTTING IT ALL TOGETHER:

# // Set the base url:
url_base = "https://api.stlouisfed.org/fred/series/observations?series_id={}&api_key=22ee7a76e736e32f54f5df0a7171538d&file_type=json"

# // Set the base fileName:
file_base = "data_FRED-{}.json"

# // Pick the series that I want:
fredSeries = [
    'PCEPI', 'CPIAUCSL', 'PAYEMS', 'DGS10', 'INDPRO', 'UNRATE',
    'LES1252881600Q'
]

# // Begin a loop, dealing with each series, one by one:
for i in fredSeries:

    # // In what follows below I print the iteration of the loop we are on:
    # // This is not necessary but can be helpful, esp with long loops:
    print("------Iteration Starts--------")
    print(i)

    # // Build the URL for this iteration of the loop, and check what we are getting:
    URL = url_base.format(i)
    print(URL)

    # // Request the html from the URL:
    data = requests.get(URL).json()
    print(data)

    # // Set the filename, and check what we are getting:
    fileName = file_base.format(i)
    print(fileName)

    # // Add some white space to our output. (This is purely so we can see what is happening below clearly)
    print("------Iteration Ends--------")

    # /// Save the file:
    with open(fileName, 'w', encoding='utf-8') as f:
        json.dump(data, f, ensure_ascii=False, indent=4)

    # /// Download the file to local machine:
    files.download(fileName)
# Out:
# ------Iteration Starts--------
# PCEPI
# https://api.stlouisfed.org/fred/series/observations?series_id=PCEPI&api_key=22ee7a76e736e32f54f5df0a7171538d&file_type=json
# {'realtime_start': '2024-02-14', 'realtime_end': '2024-02-14', 'observation_start': '1600-01-01', 'observation_end': '9999-12-31', 'units': 'lin', 'output_type': 1, 'file_type': 'json', 'order_by': 'observation_date', 'sort_order': 'asc', 'count': 780, 'offset': 0, 'limit': 100000, 'observations': [{'realtime_start': '2024-02-14', 'realtime_end': '2024-02-14', 'date': '1959-01-01', 'value': '15.164'}, {'realtime_start': '2024-02-14', 'realtime_end': '2024-02-14', 'date': '1959-02-01', 'value': '15.179'}, {'realtime_start': '2024-02-14', 'realtime_end': '2024-02-14', 'date': '1959-03-01', 'value': '15.189'}, {'realtime_start': '2024-02-14', 'realtime_end': '2024-02-14', 'date': '1959-04-01', 'value': '15.219'}, {'realtime_start': '2024-02-14', 'realtime_end': '2024-02-14', 'date': '1959-05-01', 'value': '15.227'}, {'realtime_start': '2024-02-14', 'realtime_end': '2024-02-14', 'date': '1959-06-01', 'value': '15.271'}, {'realtime_start': '2024-02-14', 'realtime_end': '2024-02-14', 'date': '1959-07-01', 'value': '15.303'}, {'realtime_start': '2024-02-14', 'realtime_end': '2024-02-14', 'date': '1959-08-01', 'value': '15.325'}, {'realtime_start': '2024-02-14', 'realtime_end': '2024-02-14', 'date': '1959-09-01', 'value': '15.365'}, {'realtime_start': '2024-02-14', 'realtime_end': '2024-02-14', 'date': '1959-10-01', 'value': '15.402'}, {'realtime_start': '2024-02-14', 'realtime_end': '2024-02-14', 'date': '1959-11-01', 'value': '15.412'}, {'realtime_start': '2024-02-14', 'realtime_end': '2024-02-14', 'date': '1959-12-01', 'value': '15.43'}, {'realtime_start': '2024-02-14', 'realtime_end': '2024-02-14', 'date': '1960-01-01', 'value': '15.421'}, {'realtime_start': '2024-02-14', 'realtime_end': '2024-02-14', 'date': '1960-02-01', 'value': '15.437'}, {'realtime_start': '2024-02-14', 'realtime_end': '2024-02-14', 'date': '1960-03-01', 'value': '15.446'}, {'realtime_start': '2024-02-14', 'realtime_end': '2024-02-14', 'date': '1960-04-01', 'value': '15.502'}, {'realtime_start': '2024-02-14', 'realtime_end': '2024-02-14', 'date': '1960-05-01', 'value': '15.518'}, {'realtime_start': '2024-02-14', 'realtime_end': '2024-02-14', 'date': '1960-06-01', 'value': '15.525'}, {'realtime_start': '2024-02-14', 'realtime_end': '2024-02-14', 'date': '1960-07-01', 'value': '15.553'}, {'realtime_start': '2024-02-14', 'realtime_end': '2024-02-14', 'date': '1960-08-01', 'value': '15.579'}, {'realtime_start': '2024-02-14', 'realtime_end': '2024-02-14', 'date': '1960-09-01', 'value': '15.588'}, {'realtime_start': '2024-02-14', 'realtime_end': '2024-02-14', 'date': '1960-10-01', 'value': '15.606'}, {'realtime_start': '2024-02-14', 'realtime_end': '2024-02-14', 'date': '1960-11-01', 'value': '15.659'}, {'realtime_start': '2024-02-14', 'realtime_end': '2024-02-14', 'date': '1960-12-01', 'value': '15.662'}, {'realtime_start': '2024-02-14', 'realtime_end': '2024-02-14', 'date': '1961-01-01', 'value': '15.665'}, {'realtime_start': '2024-02-14', 'realtime_end': '2024-02-14', 'date': '1961-02-01', 'value': '15.679'}, {'realtime_start': '2024-02-14', 'realtime_end': '2024-02-14', 'date': '1961-03-01', 'value': '15.67'}, {'realtime_start': '2024-02-14', 'realtime_end': '2024-02-14', 'date': '1961-04-01', 'value': '15.661'}, {'realtime_start': '2024-02-14', 'realtime_end': '2024-02-14', 'date': '1961-05-01', 'value': '15.67'}, {'realtime_start': '2024-02-14', 'realtime_end': '2024-02-14', 'date': '1961-06-01', 'value': '15.677'}, {'realtime_start': '2024-02-14', 'realtime_end': '2024-02-14', 'date': '1961-07-01', 'value': '15.711'}, {'realtime_start': '2024-02-14', 'realtime_end': '2024-02-14', 'date': '1961-08-01', 'value': '15.724'}, {'realtime_start': '2024-02-14', 'realtime_end': '2024-02-14', 'date': '1961-09-01', 'value': '15.742'}, {'realtime_start': '2024-02-14', 'realtime_end': '2024-02-14', 'date': '1961-10-01', 'value': '15.741'}, {'realtime_start': '2024-02-14', 'realtime_end': '2024-02-14', 'date': '1961-11-01', 'value': '15.742'}, {'realtime_start': '2024-02- ...
# data_FRED-PCEPI.json
# ------Iteration Ends--------
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# e:\OneDrive\Github\eco\courses\archive\section2\DSEP_2_0_loopsExamples.ipynb Cell 23 in <cell line: 16>()
#      <a href='vscode-notebook-cell:/e%3A/OneDrive/Github/eco/courses/archive/section2/DSEP_2_0_loopsExamples.ipynb#X32sZmlsZQ%3D%3D?line=39'>40</a>     json.dump(data, f, ensure_ascii=False, indent=4)
#      <a href='vscode-notebook-cell:/e%3A/OneDrive/Github/eco/courses/archive/section2/DSEP_2_0_loopsExamples.ipynb#X32sZmlsZQ%3D%3D?line=41'>42</a> # /// Download the file to local machine:
# ---> <a href='vscode-notebook-cell:/e%3A/OneDrive/Github/eco/courses/archive/section2/DSEP_2_0_loopsExamples.ipynb#X32sZmlsZQ%3D%3D?line=42'>43</a> files.download(fileName)
#
# NameError: name 'files' is not defined

# %% [markdown]
# **Motivation**: The ONS API is more complex than FRED since it has two parts that change: the series, and the dataset. This is common to lots of APIs, including the Economics Observatory API. This tutorial discusses how to use the string format method with named placeholders in order to form usable API urls.

# %%
# // The basic ONS API looks like this:
"https://api.ons.gov.uk/timeseries/L55O/dataset/MM23/data"

# // Click on the link above and you will see data on inflation.

# // There are TWO things that could change here, the series and the dataset.

# // Using our placholders we can write this as:
"https://api.ons.gov.uk/timeseries/{}/dataset/{}/data"

# // We will need a way to differentiate between the two placeholders.
# // This can be done using numbers or words
"https://api.ons.gov.uk/timeseries/{1}/dataset/{2}/data"

# // Our challenge now is to fill spaces {1} and {2} with the things that we want.

# // Lets try this to build some logic:

url_base = "https://api.ons.gov.uk/timeseries/{1}/dataset/{2}/data"

URL = url_base.format("mySeries", "myDataset")
print(URL)

## Why does this not work?
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# e:\OneDrive\Github\eco\courses\archive\section2\DSEP_2_0_loopsExamples.ipynb Cell 25 in <cell line: 21>()
#      <a href='vscode-notebook-cell:/e%3A/OneDrive/Github/eco/courses/archive/section2/DSEP_2_0_loopsExamples.ipynb#X33sZmlsZQ%3D%3D?line=14'>15</a> # // Our challenge now is to fill spaces {1} and {2} with the things that we want.
#      <a href='vscode-notebook-cell:/e%3A/OneDrive/Github/eco/courses/archive/section2/DSEP_2_0_loopsExamples.ipynb#X33sZmlsZQ%3D%3D?line=15'>16</a>
#      <a href='vscode-notebook-cell:/e%3A/OneDrive/Github/eco/courses/archive/section2/DSEP_2_0_loopsExamples.ipynb#X33sZmlsZQ%3D%3D?line=16'>17</a> # // Lets try this to build some logic:
#      <a href='vscode-notebook-cell:/e%3A/OneDrive/Github/eco/courses/archive/section2/DSEP_2_0_loopsExamples.ipynb#X33sZmlsZQ%3D%3D?line=18'>19</a> url_base = "https://api.ons.gov.uk/timeseries/{1}/dataset/{2}/data"
# ---> <a href='vscode-notebook-cell:/e%3A/OneDrive/Github/eco/courses/archive/section2/DSEP_2_0_loopsExamples.ipynb#X33sZmlsZQ%3D%3D?line=20'>21</a> URL = url_base.format("mySeries", "myDataset")
#      <a href='vscode-notebook-cell:/e%3A/OneDrive/Github/eco/courses/archive/section2/DSEP_2_0_loopsExamples.ipynb#X33sZmlsZQ%3D%3D?line=21'>22</a> print(URL)
#
# IndexError: Replacement index 2 out of range for positional args tuple

# %%
## Remember that positions start at 0:

url_base = "https://api.ons.gov.uk/timeseries/{1}/dataset/{2}/data"

URL2 = url_base.format("mySeries", "myDataset", "apple")
print(URL2)

## Q.  What will this code produce?
# Out:
# https://api.ons.gov.uk/timeseries/myDataset/dataset/apple/data

# %%
## Remember that positions start at 0:

url_base = "https://api.ons.gov.uk/timeseries/{0}/dataset/{1}/data"

URL3 = url_base.format("L55O", "MM23")
print(URL3)

## Q.  Run this code and test that the API works...
## ! Note that 0 and O are different!
# Out:
# https://api.ons.gov.uk/timeseries/L55O/dataset/MM23/data

# %%
## Using this practically:

url_base = "https://api.ons.gov.uk/timeseries/{0}/dataset/{1}/data"
codes = [['A', 'B'], ['C', 'D']]

URL1 = url_base.format(codes[0][0], codes[1][1])
print(URL1)
# Out:
# https://api.ons.gov.uk/timeseries/A/dataset/D/data

# %%
## Using this practically:

url_base = "https://api.ons.gov.uk/timeseries/{0}/dataset/{1}/data"
codes = [['L55O', 'MM23'], ['LZVB', 'PRDY']]

URL1 = url_base.format(codes[0][0], codes[0][1])
URL2 = url_base.format(codes[1][0], codes[1][1])
print(URL1)
print(URL2)

## Discussion: how to practically make this work for policy purposes, using GitHub to store a list of codes.
# Out:
# https://api.ons.gov.uk/timeseries/L55O/dataset/MM23/data
# https://api.ons.gov.uk/timeseries/LZVB/dataset/PRDY/data

# %%
## Using this practically:

url_base = "https://api.ons.gov.uk/timeseries/{0}/dataset/{1}/data"
longList = [['L55O', 'MM23'], ['LZVB', 'PRDY']]

for i in range(2):
    print(i)
    codes = longList[i]
    print(codes)
    URL = url_base.format(codes[0], codes[1])
    print(URL)

# Or alternatively:
print("\n")

for i in range(2):
    URL2 = url_base.format(longList[i][0], longList[i][1])
    print(URL2)

# Discussion: How can we use the example above practically to maintain data sets we use regularly using a simple CSV on GitHub?
# Out:
# 0
# ['L55O', 'MM23']
# https://api.ons.gov.uk/timeseries/L55O/dataset/MM23/data
# 1
# ['LZVB', 'PRDY']
# https://api.ons.gov.uk/timeseries/LZVB/dataset/PRDY/data
#
#
# https://api.ons.gov.uk/timeseries/L55O/dataset/MM23/data
# https://api.ons.gov.uk/timeseries/LZVB/dataset/PRDY/data
